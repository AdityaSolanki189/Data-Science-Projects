# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/housing.csv')

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
df.corr()

# %%
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
lbl = LabelEncoder()
lbl.fit_transform(df.ocean_proximity)
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
df.isna().sum()

# %%
emi = SimpleImputer(strategy='mean', missing_values=np.nan)
df['total_bedrooms'] = emi.fit_transform(df[['total_bedrooms']])

# %%
#df = df.dropna(axis='index', how='any')
#index goes row wise
#column will delete the whole column
#any or all

#fillna(inplace=True)

#drop the entire column
#df.drop('ocean_proximity', axis='column', inplace=True)

# %%
df.drop('ocean_proximity', axis='columns', inplace=True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
x = df.iloc[:,0:8]
y = df.iloc[:,8]

scaler = StandardScaler()
x_std = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_std, y , test_size=0.3, random_state=None)
print('x training shape', x_train.shape)
print('y training shape', y_train.shape)
print('x testing shape', x_test.shape)
print('y testing shape', y_test.shape)
# Out:
# x training shape (14448, 8)
# y training shape (14448,)
# x testing shape (6192, 8)
# y testing shape (6192,)

# %%
mlp = MLPRegressor(hidden_layer_sizes=(100,50), activation='relu', solver="lbfgs", max_iter=20)
mlp
# Out:
# MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=20, solver='lbfgs')

# %%
history = mlp.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
#accuracy score for training set
print(mlp.score(x_train,y_train)*100)
# Out:
# 67.57245004491747

# %%
#accuracy score for testing set
print(mlp.score(x_test,y_test)*100)
# Out:
# 68.18291590119142

# %%
y_pred = mlp.predict(x_test)
y_pred
# Out:
# array([374239.0655448 , 193143.46961773,  93266.14849394, ...,
#        300960.46767564, 371785.47763231, 273243.04133181])

# %%
y_test
# Out:
# 10640    340000.0
# 9510     144000.0
# 19974     65700.0
# 1625     370200.0
# 14428    212500.0
#            ...
# 17569    250000.0
# 1541     469400.0
# 20199    228900.0
# 9018     318500.0
# 9334     255400.0
# Name: median_house_value, Length: 6192, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_squared_log_error

print(r2_score(y_test, y_pred))
print(mean_squared_log_error(y_test, y_pred))
# Out:
# 0.6818291590119142
# 0.10573359322039032

# %%
df_temp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_temp.head()
# Out:
#      Actual      Predicted
# 0  500001.0  683653.557278
# 1  188500.0  247188.467737
# 2  199600.0  221988.077243
# 3  240600.0  247999.691110
# 4  251400.0  177443.801956

# %%
df_temp = df_temp.head(30)
df_temp.plot(kind='bar',figsize=(10,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 46382.5925959568
# Mean Squared Error: 4276687159.732031
# Root Mean Squared Error: 65396.384913327056

# %%
plt.plot(mlp.loss_curve_)
plt.title("Loss Curve", fontsize=14)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-9e3be05d1758> in <module>()
#       1
# ----> 2 plt.plot(mlp.loss_curve_)
#       3 plt.title("Loss Curve", fontsize=14)
#       4 plt.xlabel('Iterations')
#       5 plt.ylabel('Cost')
#
# AttributeError: 'MLPRegressor' object has no attribute 'loss_curve_'
