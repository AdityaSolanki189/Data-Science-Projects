# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
image1 =io.imread("/content/download (1).jpg")

# %%
cv_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=274x184 at 0x7F9D6C6583D0>

# %%
gray = cv.cvtColor(image1, cv.COLOR_BGR2RGB)

# %%
cv_imshow(gray)
# Out:
# <PIL.Image.Image image mode=RGB size=274x184 at 0x7F9D6C658D10>

# %%
image=io.imread("/content/download.jpg")
gray = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# %%
cv_imshow(gray)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C6A1B10>
# -1

# %%
cv_imshow(image)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C6AEB90>
# -1

# %%
image.shape
# Out:
# (194, 259, 3)

# %%
corner=image[0:100,0:100]

# %%
cv_imshow(corner)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F9D6C63C510>
# -1

# %%
canvas = np.zeros((300, 300, 3), dtype = "uint8")
#RGB(255,255,255)
green = (0, 255, 0)
cv.line(canvas, (0, 0), (300, 300), green,4)
cv_imshow(canvas)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F9D6C63C190>
# -1

# %%
red = (0, 0, 255)
cv.line(canvas, (300, 0), (0, 300), red, 3)
cv_imshow(canvas)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F9D6C63C910>
# -1

# %%
M = np.float32([[1, 0, 25], [0, 1, 50]])
print(image.shape[0])
print(image.shape[1])
shifted = cv.warpAffine(image, M, (image.shape[1], image.shape[0]))
cv_imshow(shifted)
cv.waitKey(0)
# Out:
# 194
# 259
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C658810>
# -1

# %%
# Rotation
cv_imshow(image)
(h, w) = image.shape[:2]

center = (w // 2, h // 2)
M = cv.getRotationMatrix2D(center, 45, 1.0)  #(point of rotation, angle, scale)
rotated = cv.warpAffine(image, M, (w, h))
cv_imshow(rotated)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C663690>
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C63C950>
# -1

# %%
cv_imshow(image)
print(image.shape)
r = 150.0 / image.shape[1]
dim = (150, int(image.shape[0] * r))
resized = cv.resize(image, dim, interpolation = cv.INTER_AREA)
print(resized.shape)
cv_imshow(resized)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C6AED10>
# (194, 259, 3)
# (112, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x112 at 0x7F9D6C6AEA50>
# -1

# %%
cv_imshow(image)
flipped = cv.flip(image, 0)  #0 for flipping horizonatlly
cv_imshow(flipped)
cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C6866D0>
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F9D6C658390>
# -1
