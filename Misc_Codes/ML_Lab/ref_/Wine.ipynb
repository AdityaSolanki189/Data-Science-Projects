# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('..\..\datasets\Wine.csv')

# %%
pr
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\ml\lib\site-packages\sklearn\utils\__init__.py:117, in Bunch.__getattr__(self, key)
#     <a href='file:///c%3A/Users/adity/anaconda3/envs/ml/lib/site-packages/sklearn/utils/__init__.py?line=115'>116</a> try:
# --> <a href='file:///c%3A/Users/adity/anaconda3/envs/ml/lib/site-packages/sklearn/utils/__init__.py?line=116'>117</a>     return self[key]
#     <a href='file:///c%3A/Users/adity/anaconda3/envs/ml/lib/site-packages/sklearn/utils/__init__.py?line=117'>118</a> except KeyError:
#
# KeyError: 'shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\adity\OneDrive\Documents\GitHub\Data-Science-Projects\Misc_Codes\ML_Lab\ref_\Wine.ipynb Cell 3' in <module>
# ...

# %%
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
cnt = df.count()
print(cnt)
# Out:
# Alcohol                 178
# Malic_Acid              178
# Ash                     178
# Ash_Alcanity            178
# Magnesium               178
# Total_Phenols           178
# Flavanoids              178
# Nonflavanoid_Phenols    178
# Proanthocyanins         178
# Color_Intensity         178
# Hue                     178
# OD280                   178
# Proline                 178
# Customer_Segment        178
# dtype: int64

# %%
print(df.Customer_Segment.value_counts())
df.Customer_Segment.value_counts().plot(kind='bar')
plt.show()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Customer_Segment, dtype: int64

# %%
df.plot(subplots= True, figsize = (14,14))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
import seaborn as sns

# %%
sns.barplot(data = df, y = 'Alcohol', x= 'Customer_Segment')
plt.show()
sns.barplot(data = df, y = 'Ash', x = 'Customer_Segment')
plt.show()

# %%
fig, ax = plt.subplots(5,3 , figsize = (15,20))
sns.barplot(data = df, y='Alcohol',              x ='Customer_Segment' ,ax = ax[0,0])
sns.barplot(data = df, y='Malic_Acid',           x = 'Customer_Segment', ax = ax[0,1])
sns.barplot(data = df, y='Ash',                 x = "Customer_Segment", ax = ax[0,2])
sns.barplot(data = df, y='Ash_Alcanity',        x = 'Customer_Segment', ax = ax[1,0])
sns.barplot(data = df, y='Magnesium',          x = 'Customer_Segment', ax = ax[1,1])
sns.barplot(data = df, y='Total_Phenols',          x = 'Customer_Segment', ax = ax[1,2])
sns.barplot(data = df, y='Flavanoids ',          x = 'Customer_Segment', ax = ax[2,0])
sns.barplot(data = df, y='Nonflavanoid_Phenols',          x = 'Customer_Segment', ax = ax[2,1])
sns.barplot(data = df, y='Proanthocyanins',          x = 'Customer_Segment', ax = ax[2,2])
sns.barplot(data = df, y='Color_Intensity',          x = 'Customer_Segment', ax = ax[3,0])
sns.barplot(data = df, y='Hue',          x = 'Customer_Segment', ax = ax[3,1])
sns.barplot(data = df, y='OD280 ',          x = 'Customer_Segment', ax = ax[3,2])
sns.barplot(data = df, y='Proline',          x = 'Customer_Segment', ax = ax[4,0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19192/2250215724.py in <module>
#       6 sns.barplot(data = df, y='Magnesium',          x = 'Customer_Segment', ax = ax[1,1])
#       7 sns.barplot(data = df, y='Total_Phenols',          x = 'Customer_Segment', ax = ax[1,2])
# ----> 8 sns.barplot(data = df, y='Flavanoids ',          x = 'Customer_Segment', ax = ax[2,0])
#       9 sns.barplot(data = df, y='Nonflavanoid_Phenols',          x = 'Customer_Segment', ax = ax[2,1])
#      10 sns.barplot(data = df, y='Proanthocyanins',          x = 'Customer_Segment', ax = ax[2,2])
#
# D:\Software\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
