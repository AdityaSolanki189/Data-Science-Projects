# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report ,f1_score, plot_roc_curve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

from sklearn.metrics import plot_confusion_matrix

# %%
df = pd.read_csv('D:\\Software\\Anaconda\\ANA_Codes\\Data\\breast-cancer.csv')

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
y = df.diagnosis

# %%
#label encoding
lb = LabelEncoder()
df.diagnosis = lb.fit_transform(y)

# %%
df.head(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
x = df.iloc[:,2:32]
print('X shape',x.shape)
# Out:
# X shape (569, 30)

# %%
scaler = StandardScaler()
x_std = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_std, y, test_size = 0.37, random_state = 0)

# %%
svc = svm.SVC(C = 0.4, kernel = 'linear')

# %%
svc.fit(x_train,y_train)
# Out:
# SVC(C=0.4, kernel='linear')

# %%
print(svc.score(x_train,y_train)*100)
# Out:
# 98.60335195530726

# %%
print(svc.score(x_test, y_test)*100)
# Out:
# 98.5781990521327

# %%
plot_confusion_matrix (svc, x_test, y_test)

# %%
y_pred = svc.predict(x_test)
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            B       0.99      0.99      0.99       134
#            M       0.97      0.99      0.98        77
#
#     accuracy                           0.99       211
#    macro avg       0.98      0.99      0.98       211
# weighted avg       0.99      0.99      0.99       211

# %%
plot_roc_curve(svc, x_test, y_test)

# %%
#seaborn
import seaborn as sns

# %%
y_cplot = sns.countplot(y, label= "Count")
B, M = y_cplot.value.counts()
print ('Number of Benign', B )
print('Number of Malignant', M)
# Out:
# D:\Software\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15712/945719438.py in <module>
#       1 y_cplot = sns.countplot(y, label= "Count")
# ----> 2 B,M = y_cplot.value.counts()
#       3 print ('Number of Benign', B )
#       4 print('Number of Malignant', M)
#
# AttributeError: 'AxesSubplot' object has no attribute 'value'

# %%
plt.subplots(figsize=(9, 9))
corr_mat = sns.heatmap(x.corr(), annot=False, linewidths=.5)

# %%
plt.subplots(figsize=(16, 16))
corr_mat = sns.heatmap(x.corr(), annot=True, linewidths=1)
