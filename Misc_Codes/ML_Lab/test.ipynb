# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("\datasets\breast-cancer.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\adity\OneDrive\Documents\GitHub\Data-Science-Projects\Misc_Codes\ML_Lab\test.ipynb Cell 2' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adity/OneDrive/Documents/GitHub/Data-Science-Projects/Misc_Codes/ML_Lab/test.ipynb#ch0000001?line=0'>1</a> df=pd.read_csv("\datasets\breast-cancer.csv")
#
# ...
