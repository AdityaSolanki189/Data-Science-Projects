# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\adity\OneDrive\Documents\GitHub\Data-Science-Projects\Misc_Codes\ML_Lab\sample_ProblemStatements\CervixCancer_KMeans.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adity/OneDrive/Documents/GitHub/Data-Science-Projects/Misc_Codes/ML_Lab/sample_ProblemStatements/CervixCancer_KMeans.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/adity/OneDrive/Documents/GitHub/Data-Science-Projects/Misc_Codes/ML_Lab/sample_ProblemStatements/CervixCancer_KMeans.ipynb#ch0000000?line=1'>2</a> from matplotlib import pyplot as plt
# ...

# %%
df=pd.read_csv('../../datasets/sobar-72.csv')

# %%
df.head()
# Out:
#    behavior_sexualRisk  behavior_eating  behavior_personalHygine  \
# 0                   10               13                       12
# 1                   10               11                       11
# 2                   10               15                        3
# 3                   10               11                       10
# 4                    8               11                        7
#
#    intention_aggregation  intention_commitment  attitude_consistency  \
# 0                      4                     7                     9
# 1                     10                    14                     7
# 2                      2                    14                     8
# 3                     10                    15                     7
# 4                      8                    10                     7
#
#    attitude_spontaneity  norm_significantPerson  norm_fulfillment  \
# 0                    10                       1                 8
# ...

# %%
km=KMeans(n_clusters=2, max_iter=400,verbose=True,tol=0.2)
pred = km.fit_predict(df[['behavior_sexualRisk','behavior_eating','behavior_personalHygine','intention_aggregation','intention_commitment','attitude_consistency','attitude_spontaneity','norm_significantPerson','norm_fulfillment','perception_vulnerability','perception_severity','motivation_strength','motivation_willingness','socialSupport_emotionality','socialSupport_appreciation','socialSupport_instrumental','empowerment_knowledge','empowerment_abilities','empowerment_desires']])
# plt.scatter(df['B'], df['C'],c=df['A'])
score = accuracy_score(df['ca_cervix'], pred)
score
# Out:
# Initialization complete
# Iteration 0, inertia 18544.0
# Iteration 1, inertia 10943.945451408525
# Iteration 2, inertia 10741.51691581432
# Converged at iteration 2: center shift 0.7277826921565068 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 16456.0
# Iteration 1, inertia 12425.620370370372
# Converged at iteration 1: center shift 2.11794148887263 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 26696.0
# Iteration 1, inertia 10981.594772306838
# Converged at iteration 1: center shift 1.4320422484818636 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 20378.0
# Iteration 1, inertia 12748.726336632135
# Iteration 2, inertia 12523.077575105548
# Iteration 3, inertia 12397.339506172839
# Converged at iteration 3: center shift 1.3144021394096472 within tolerance 2.2867690058479537.
# Initialization complete
# Iteration 0, inertia 21202.0
# ...

# %%
plt.scatter(df['behavior_eating'], df['behavior_personalHygine'],c=pred)
plt.scatter(km.cluster_centers_[:,0] ,km.cluster_centers_[:,1], color='black')
